# %%
tags = ["dog", "cat", "rat", "charm", "fat"]
names = ["dog", "mouse", "charm", "charm"]

# %%
one_hot = [0]*len(tags)
for n in names:
    if n in tags:
        i = tags.index(n)
        one_hot[i] = 1
    else: print (n)
# Out:
# mouse

# %%
print(one_hot)
# Out:
# [1, 0, 0, 1, 0]

# %%
import testparse

# %%
x = testparse.XML_preprocessor("basketball/Annotations/")
# Out:
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# ...

# %%
from imp import reload
reload(testparse)
# Out:
# <module 'testparse' from 'testparse.py'>

# %%
x = testparse.XML_preprocessor("basketball/Annotations/")
# Out:
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# n02802426
# ...

# %%
for i, k  in enumerate(x.classes):
    print i, k
# Out:
# 0 container
# 1 water
# 2 bird bath
# 3 tire
# 4 wheelbarrow
# 5 bucket
# 6 gutter
# 7 vegetation
