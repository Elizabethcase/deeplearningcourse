# %%
import os
import sys
import random
import exifread
import piexif
from PIL import Image
import matplotlib

# %matplotlib inline

import numpy as np

import pandas as pd

import xml.etree.ElementTree as ET

#from datasets.dataset_utils import int64_feature, float_feature, bytes_feature
#from datasets.pascalvoc_common import VOC_LABELS

#from datasets.CUSTOM_common import CLASS_LABELS

# %%
os.chdir('/Users/elizabeth/Box Sync/SSD-Tensorflow')

# %%
#from datasets.dataset_utils import int64_feature, float_feature, bytes_feature
#from datasets.pascalvoc_common import VOC_LABELS

CLASS_LABELS = {
    'none': (0, 'Background'),
    'flower pot': (1, 'Container'),
    'container': (2, 'Container'),
    'porch': (3, 'Cover'),
    'toy': (4, 'Toy'),
    'bucket': (5, 'Container'),
    'basketball': (6, 'Toy'),
    'car': (7, 'Vehicle'),
    'tarp': (8, 'Cover'),
    'gutter': (9, 'Container'),
    'albo property': (10, 'Presence'),
    'no albo property': (11, 'Presence'),
    'trash bin': (12, 'Container'),
    'pot': (13, 'Container'),
    'tarp': (14, 'Container'),
    'table': (15, 'Other'),
    'umbrella': (16, 'Cover'),
    'car': (17, 'Other'),
    'air conditioner': (18, 'Container'),
    'flower bed': (19, 'Other'),
    'drain': (20, 'Other')
}

# %%
directory = '/Users/elizabeth/Box Sync/deeplearningcourse/elizabeth/data/harrison_fieldwork1/annotations_wks1_2/correct_xml/'

os.chdir(directory)
# !pwd
# Out:
# /Users/elizabeth/Box Sync/deeplearningcourse/elizabeth/data/harrison_fieldwork1/annotations_wks1_2/correct_xml

# %% [markdown]
# ## Gets a count of each of the instances of the classes, total and # of photos

# %%
COUNT = {key:[0,0] for key in CLASS_LABELS.keys()}
NEW = {}

def get_counts_of_classes(directory, shape=[512,512]):

    ''' This gets the counts of all the classes in a batch of xml files.
        Directory: directory where annotations (.xml) files are stored.
        Shape: desired shape of photos; WEIRDOS will tell you if it's not that shape.

        Returns three dicts:
            1. count (shows labels that you have specified & # of appearances)
            2. new (shows labels that you did not specify & # of appearances)
            3. weirdos (returns dimensions of photographs if they don't meet your size)

    '''

    for r, dirs, files in os.walk(directory):
        
        WEIRDOS = {(file[0:-4]+'.JPG'):[0,0] for file in files}

        for f in files:
            #print(f[0:-4])
            # Read the XML annotation file.
            path = os.path.join(directory,f)
            tree = ET.parse(path)
            root = tree.getroot()
            
            f = f[0:-4]+'.JPG'

            shape_tree = root.find('size')
            if int(shape_tree.find('width').text) != shape[0]:
                WEIRDOS[f][0] = shape_tree.find('width').text
            elif int(shape_tree.find('height').text) != shape[1]:
                WEIRDOS[f][1] = shape_tree.find('height').text
            else:
                WEIRDOS.pop(f)
            
            for obj in root.findall('object'):
                label = obj.find('name').text
                
                if label in CLASS_LABELS.keys():
                    COUNT[label][0] += 1
                elif label == 'garbage bin':
                    COUNT['trash bin'][0] +=1
                else:
                    if label not in NEW:
                        NEW[label] = 1
                    else:
                        NEW[label] += 1
    
    return COUNT, NEW, WEIRDOS

# %%
count, new, weirdos = get_counts_of_classes(directory)

# %% [markdown]
# ## Creates panda dataframe of lat/lon info from GPS file

# %%
os.chdir('../../images_wks1_2/')

# %%
photos = pd.DataFrame(index=weirdos.keys())

files = [key for key in weirdos.keys()]

for j in files :

    f = open(j, 'rb')

    # Return Exif tags
    tags = exifread.process_file(f, stop_tag='GPS')
    
    #extracts lat/lon/date/alt (if present) data 
    lat = tags['GPS GPSLatitude'].values
    lon = tags['GPS GPSLongitude'].values
    date = tags['GPS GPSDate'].values
    
    try:
        alt = tags['GPS GPSAltitude'].values
        alt = float(alt[0].num/alt[0].den)
    except KeyError:
        alt = 'NaN'
    
    #turns lat/lon deg, minute, second into decimal values
    lat = dms2dec(lat)
    lon = dms2dec(lon)
    #lat = [float(i.num/i.den) for i in lat]
    #lon = [float(i.num/i.den) for i in lon]

    #lat_dec = lat[0] + (lat[1])/60 + lat[2]/3600
    #lon_dec = lon[0] + (lon[1])/60 + lon[2]/3600
    
    #adds to dataframe
    photos.loc[(j,'lat')]=lat_dec
    photos.loc[(j,'lon')] = -lon_dec
    photos.loc[(j,'date_taken')] = date
    photos.loc[(j,'alt')] = alt
    #holder for heading info
    photos['heading'] = ''
    
photos['notes'] = 'alt values for G00 are not accurate'

# %%
photos
# Out:
#                        lat        lon  date_taken   alt heading  \
# G0013876_17.JPG  40.966944 -73.734444  2017:07:20   3.0
# G0013831_11.JPG  40.966944 -73.734444  2017:07:20  19.0
# G0024071_23.JPG  40.966944 -73.734444  2017:07:20   6.0
# G0036463_20.JPG  40.966944 -73.734444  2017:08:03  15.0
# G0024086_11.JPG  40.966944 -73.734444  2017:07:20  13.0
# G0024083_18.JPG  40.966944 -73.734444  2017:07:20  10.0
# G0024036_19.JPG  40.966944 -73.734444  2017:07:20  10.0
# G0024076_11.JPG  40.966944 -73.734444  2017:07:20  12.0
# G0024050_23.JPG  40.966944 -73.734444  2017:07:20   2.0
# G0024059_17.JPG  40.966944 -73.734444  2017:07:20   5.0
# G0024062_22.JPG  40.966944 -73.734444  2017:07:20   4.0
# G0036449_23.JPG  40.966944 -73.734444  2017:08:03   9.0
# G0024085_22.JPG  40.966944 -73.734444  2017:07:20  13.0
# G0024060_19.JPG  40.966944 -73.734444  2017:07:20   4.0
# G0013854_22.JPG  40.966944 -73.734444  2017:07:20   4.0
# G0024055_17.JPG  40.966944 -73.734444  2017:07:20   0.0
# G0024057_5.JPG   40.966944 -73.734444  2017:07:20   4.0
# G0024087_22.JPG  40.966944 -73.734444  2017:07:20  13.0
# G0036435_11.JPG  40.966944 -73.734444  2017:08:03   5.0
# G0024070_22.JPG  40.966944 -73.734444  2017:07:20   4.0
# G0013833_20.JPG  40.966944 -73.734444  2017:07:20   4.0
# G0036464_20.JPG  40.966944 -73.734444  2017:08:03  15.0
# G0013859_19.JPG  40.966944 -73.734444  2017:07:20   4.0
# G0024087_21.JPG  40.966944 -73.734444  2017:07:20  13.0
# G0013831_21.JPG  40.966944 -73.734444  2017:07:20  19.0
# G0024075_19.JPG  40.966944 -73.734444  2017:07:20  10.0
# G0013856_22.JPG  40.966944 -73.734444  2017:07:20   1.0
# G0024030_11.JPG  40.966944 -73.734444  2017:07:20  13.0
# G0024044_19.JPG  40.966944 -73.734444  2017:07:20   0.0
# G0024019_21.JPG  40.966944 -73.734444  2017:07:20   3.0
# ...                    ...        ...         ...   ...     ...
# G0024041_11.JPG  40.966944 -73.734444  2017:07:20   3.0
# G0036452_21.JPG  40.966944 -73.734444  2017:08:03   9.0
# G0024084_11.JPG  40.966944 -73.734444  2017:07:20  11.0
# G0013868_23.JPG  40.966944 -73.734444  2017:07:20   1.0
# G0036463_21.JPG  40.966944 -73.734444  2017:08:03  15.0
# G0013833_17.JPG  40.966944 -73.734444  2017:07:20   4.0
# G0024051_11.JPG  40.966944 -73.734444  2017:07:20   4.0
# G0013836_19.JPG  40.966944 -73.734444  2017:07:20   2.0
# G0013879_5.JPG   40.966944 -73.734444  2017:07:20   5.0
# G0013832_5.JPG   40.966944 -73.734444  2017:07:20  10.0
# G0024018_21.JPG  40.966944 -73.734444  2017:07:20   4.0
# G0036499_17.JPG  40.966944 -73.734444  2017:08:03  16.0
# G0024022_20.JPG  40.966944 -73.734444  2017:07:20   5.0
# G0024017_17.JPG  40.966944 -73.734444  2017:07:20   4.0
# G0024055_11.JPG  40.966944 -73.734444  2017:07:20   0.0
# G0024040_20.JPG  40.966944 -73.734444  2017:07:20   3.0
# G0013877_5.JPG   40.966944 -73.734444  2017:07:20   5.0
# G0024061_23.JPG  40.966944 -73.734444  2017:07:20   3.0
# G0024062_20.JPG  40.966944 -73.734444  2017:07:20   4.0
# G0036499_18.JPG  40.966944 -73.734444  2017:08:03  16.0
# G0024017_5.JPG   40.966944 -73.734444  2017:07:20   4.0
# G0024062_19.JPG  40.966944 -73.734444  2017:07:20   4.0
# G0013877_21.JPG  40.966944 -73.734444  2017:07:20   5.0
# G0024017_11.JPG  40.966944 -73.734444  2017:07:20   4.0
# G0013858_5.JPG   40.966944 -73.734444  2017:07:20   1.0
# G0024033_11.JPG  40.966944 -73.734444  2017:07:20  20.0
# G0024067_19.JPG  40.966944 -73.734444  2017:07:20   2.0
# G0024089_23.JPG  40.966944 -73.734444  2017:07:20  12.0
# G0024068_11.JPG  40.966944 -73.734444  2017:07:20   2.0
# G0036460_17.JPG  40.966944 -73.734444  2017:08:03  15.0
#
#                                                notes
# G0013876_17.JPG  alt values for G00 are not accurate
# G0013831_11.JPG  alt values for G00 are not accurate
# G0024071_23.JPG  alt values for G00 are not accurate
# G0036463_20.JPG  alt values for G00 are not accurate
# G0024086_11.JPG  alt values for G00 are not accurate
# G0024083_18.JPG  alt values for G00 are not accurate
# G0024036_19.JPG  alt values for G00 are not accurate
# G0024076_11.JPG  alt values for G00 are not accurate
# G0024050_23.JPG  alt values for G00 are not accurate
# G0024059_17.JPG  alt values for G00 are not accurate
# G0024062_22.JPG  alt values for G00 are not accurate
# G0036449_23.JPG  alt values for G00 are not accurate
# G0024085_22.JPG  alt values for G00 are not accurate
# G0024060_19.JPG  alt values for G00 are not accurate
# G0013854_22.JPG  alt values for G00 are not accurate
# G0024055_17.JPG  alt values for G00 are not accurate
# G0024057_5.JPG   alt values for G00 are not accurate
# G0024087_22.JPG  alt values for G00 are not accurate
# G0036435_11.JPG  alt values for G00 are not accurate
# G0024070_22.JPG  alt values for G00 are not accurate
# G0013833_20.JPG  alt values for G00 are not accurate
# G0036464_20.JPG  alt values for G00 are not accurate
# G0013859_19.JPG  alt values for G00 are not accurate
# G0024087_21.JPG  alt values for G00 are not accurate
# G0013831_21.JPG  alt values for G00 are not accurate
# G0024075_19.JPG  alt values for G00 are not accurate
# G0013856_22.JPG  alt values for G00 are not accurate
# G0024030_11.JPG  alt values for G00 are not accurate
# G0024044_19.JPG  alt values for G00 are not accurate
# G0024019_21.JPG  alt values for G00 are not accurate
# ...                                              ...
# G0024041_11.JPG  alt values for G00 are not accurate
# G0036452_21.JPG  alt values for G00 are not accurate
# G0024084_11.JPG  alt values for G00 are not accurate
# G0013868_23.JPG  alt values for G00 are not accurate
# G0036463_21.JPG  alt values for G00 are not accurate
# G0013833_17.JPG  alt values for G00 are not accurate
# G0024051_11.JPG  alt values for G00 are not accurate
# G0013836_19.JPG  alt values for G00 are not accurate
# G0013879_5.JPG   alt values for G00 are not accurate
# G0013832_5.JPG   alt values for G00 are not accurate
# G0024018_21.JPG  alt values for G00 are not accurate
# G0036499_17.JPG  alt values for G00 are not accurate
# G0024022_20.JPG  alt values for G00 are not accurate
# G0024017_17.JPG  alt values for G00 are not accurate
# G0024055_11.JPG  alt values for G00 are not accurate
# G0024040_20.JPG  alt values for G00 are not accurate
# G0013877_5.JPG   alt values for G00 are not accurate
# G0024061_23.JPG  alt values for G00 are not accurate
# G0024062_20.JPG  alt values for G00 are not accurate
# G0036499_18.JPG  alt values for G00 are not accurate
# G0024017_5.JPG   alt values for G00 are not accurate
# G0024062_19.JPG  alt values for G00 are not accurate
# G0013877_21.JPG  alt values for G00 are not accurate
# G0024017_11.JPG  alt values for G00 are not accurate
# G0013858_5.JPG   alt values for G00 are not accurate
# G0024033_11.JPG  alt values for G00 are not accurate
# G0024067_19.JPG  alt values for G00 are not accurate
# G0024089_23.JPG  alt values for G00 are not accurate
# G0024068_11.JPG  alt values for G00 are not accurate
# G0036460_17.JPG  alt values for G00 are not accurate
#
# [179 rows x 6 columns]

# %% [markdown]
# ## Read in addresses from csv

# %%
addresses = pd.read_csv('/Users/elizabeth/Box Sync/deeplearningcourse/elizabeth/data/addresses_lat_lon_wks23.csv')

# %%
#use L2 norm to return address shortest distance from photo

compared = addresses.loc[((addresses['Latitude']-photos['lat'][0])**2+
                          (addresses['Longitude']-photos['lon'][0])**2).argsort()[:1]]

# %%
def find_nearest_gps(pd1,pd2,
                     pd1_lat='lat',pd1_lon='lon',
                     pd2_lat='Latitude',pd2_lon='Longitude',pd2_add='Formatted address'):

    '''Functionality is not broad. Works for specific instance where you have two pandas data frames:
    
        takes:
        
        pd1 = DataFrame indexed by photo name with pd1_lat, pd1_lon columns
        pd2 = DataFrame that includes address, lat, lon as specified in assignment
    '''
    
    for f in pd1.index.values:
        top = pd2.loc[((pd2[pd2_lat]-pd1.loc[f,pd1_lat])**2+
                              (pd2[pd2_lon]-pd1.loc[f,pd1_lon])**2).argsort()[:1]]

        pd1.loc[(f,'nearest_address')] = top[pd2_add].values[0]
        pd1.loc[(f,'add_lat')] = top[pd2_lat].values[0]
        pd1.loc[(f,'add_lon')] = top[pd2_lon].values[0]
        
    
    return pd1

# %%
test = find_nearest_gps(photos, addresses)

# %%
os.chdir('./testingexif')

# %%
#successfully overwrites GPS data

# %%
def deg_rad(inp,key='deg2rad'):
    '''
        Converts degrees to radian or vice versa
        Inp = # to change
        Indicate with key = {deg2rad, rad2deg}
        
        Returns # in radian or degrees, depending on what you specified
        
    '''
    if key=='deg2rad':
        rad = inp*np.pi/180
        return rad
    
    elif key=='rad2deg':
        deg = inp*180/np.pi
        return deg

def len_at_lat(lat):
    
    '''
        Lat = latitude where info is desired
        
        Returns the length in meters of one degree, latitude or longitude, at a specified latitude
        Also returns conversion rate from degrees to meters
        
    '''
    
    #length of 1 degree in meters at a specified latitude
    m_per_lat = 111132.92-559.82*np.cos(2*phi) +1.175*np.cos(4*phi) -0.0023*np.cos(6*phi)
    m_per_lon = 111412.84*np.cos(phi) -93.5*np.cos(3*phi) -0.118*np.cos(5*phi)
    
    #number of seconds per meter
    lat_per_m = 1/m_per_lat
    lon_per_m = 1/m_per_lon
    
    return m_per_lat, m_per_lon, lat_per_m, lon_per_m

def dms2dec(inp):
    
    '''
        Converts inp from degrees, minutes, seconds to decimal
        Expects input to be type Ratio
        Returns converted input
    '''
    
    inp = [float(i.num/i.den) for i in inp]
    inp = inp[0] + (inp[1])/60 + inp[2]/3600
    
    return inp

# %% [markdown]
# ### Note that right now all testing is going on below

# %%
px500 = 5.6 #m

lat_step = 5.6*lat_per_m # whatever step sizes you're taking (250px to centerline since photos are 500x500)
lon_step = 5.6*lon_per_m

#heading -- 0 for north, 90 if photo is turned east, etc; heading from north
theta = 0

#rotaion matrix [x';y'] = [cos -sin; sin cos][x;y]
del_lon= lat_step*np.cos(theta) - lon_step*np.sin(theta) 
del_lat = lat_step*np.sin(theta) +lon_step*np.cos(theta)

w = 3000
h = 2000
crop = 500

stepw = len(range(0,w,crop))
steph = len(range(0,h,crop))

def change_GPS_exif(dict_of_files,path_to_open,path_to_save)
      
    photo_info = {key:[0,0,0] for key in pd.keys()} #lat, lon

    files = [key for key in dict_of_files.keys()]

    for j in files :

        f = open(path_to_open+j, 'rb')

        # Return Exif tags
        exif_dict = piexif.load

        lat = dms2dec(tags['GPS GPSLatitude'].values)
        lon = dms2dec(tags['GPS GPSLongitude'].values)
        
        #longitude
        if c==stepw*0 | c==stepw*1 | c==stepw*2 | c==stepw*3:# | stepw*4 | stepw*5:
            new_lon = lon - (stepw/2-0.5)*del_lon

        elif c==stepw*0+1 | c==stepw*1+1 | c==stepw*2+1 | c==stepw*3+1:#| stepw*4+1 | stepw*5+1:
            new_lon = lon - (stepw/2-1.5)*del_lon

        elif c==stepw*0+2 | c==stepw*1+2 | c==stepw*2+2 | c==stepw*3+2:
            new_lon = lon - (stepw/2-2.5)*del_lon

        elif c==stepw*0+3 | c==stepw*1+3 | c==stepw*2+3 | c==stepw*3+3:
            new_lon = lon + (stepw/2-2.5)*del_lon

        elif c==stepw*0+4 | c==stepw*1+4 | c==stepw*2+4 | c==stepw*3+4:
            new_lon = lon + (stepw/2-1.5)*del_lon

        elif c==stepw*0+5 | c==stepw*1+5 | c==stepw*2+5 | c==stepw*3+5:
            new_lon = lon + (stepw/2-.5)*del_lon
        else:
            print('lon num not defined')
            new_lon=lon
        
        #latitude
        if c in range(0,1*stepw):
            new_lat = lat + (steph/2-0.5)*lat_step
        elif c in range(1*stepw,2*stepw):
            new_lat = lat + (steph/2-1.5)*lat_step
        elif c in range(2*stepw,3*stepw):
            new_lat = lat + (steph/2-1.5)*lat_step
        elif c in range(3*stepw,4*stepw):
            new_lat = lat + (steph/2-0.5)*lat_step
        else:
            print('lat num not defined' )
            new_lat=lat
        
        exif_dict['GPS'][2] = new_lat
        exif_dict['GPS'][4] = new_lon
        
        exif_bytes = piexif.dump(exifdict)
        im = Image.open(f)
        im.save(path_to_save+f, exif=exif_bytes)
        
        return lat,lon,new_lat,new_lon
# Out:
#   File "<ipython-input-128-1a373f807d39>", line 23
#     def change_GPS_exif(table,path_to_directory,)
#                                                  ^
# SyntaxError: invalid syntax

# %%
range(stepw,2*stepw)
# Out:
# [6, 7, 8, 9, 10, 11]

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(10,8))
photos.plot.scatter('lon','lat')
plt.xlim(photos['lon'].min()-.001, photos['lon'].max()+.001)
plt.ylim(photos['lat'].min()-.001, photos['lat'].max()+.001)
plt.gca().invert_xaxis
plt.title("Unique photos in go pro wks 1/2 set in Mamaroneck\n")
# Out:
# Text(0.5,1,u'Unique photos in go pro wks 1/2 set in Mamaroneck\n')

# %%
#500 px = 5.6 m
#250 px = 2.8 m

new_lat = 0
new_lon = 0

lat_step = 5.6*lat_per_m # whatever step sizes you're taking (250px to centerline since photos are 500x500)
lon_step = 5.6*lon_per_m

theta = 0 #0 for north, 90 if photo is turned east, etc; heading from north

#rotaion matrix [x';y'] = [cos -sin; sin cos][x;y]
del_lon= lat_step*np.cos(theta) - lon_step*np.sin(theta) 
del_lat = lat_step*np.sin(theta) +lon_step*np.cos(theta)

w = 3000
h = 2000
crop = 500

stepw = len(range(0,w,crop))
steph = len(range(0,h,crop))

# %%
stepw*0+4
# Out:
# 4

# %% [markdown]
# ## CHANGE LAT/LON IN PD TABLE AND APPEND

# %%
#photo & splicing info
w = 3000
h = 2000
crop = 500

#how many times thigns should be done.. working on making this a generalizable function
stepw = len(range(0,w,crop))
steph = len(range(0,h,crop))

# %%
pd1.loc[i,'lon']
# Out:
# -73.734444444444449

# %%
pd1 = photos.copy()

#splices crop slice number from file name

for i in pd1.index.values:
    
    lat = pd1.loc[i,'lat']
    lon = pd1.loc[i,'lon']
    
    #conversions between meters per degree and degrees per meter
    m_per_lat, m_per_lon, lat_per_m, lon_per_m = len_at_lat(lat)
    
    #lat change equivalent depending on ground sampling distance of photo 
    #note -- explain how you got px500
    lat_step = px500*lat_per_m
    lon_step = px500*lon_per_m
    
    #heading -- 0 for north, 90 if photo is turned east, etc; heading from north
    theta = 0

    #rotaion matrix [x';y'] = [cos -sin; sin cos][x;y]
    del_lon= lat_step*np.cos(theta) - lon_step*np.sin(theta) 
    del_lat = lat_step*np.sin(theta) +lon_step*np.cos(theta)
    
    #returns number appended to photo, which tells where it was in the mogrify crop/splice functio
    c = int(re.sub("[^0-9]","",i[-6:]))

    if c in [stepw*0, stepw*1, stepw*2, stepw*3]:
        new_lon = lon - (stepw/2-0.5)*del_lon
        print('new lon=',new_lon)

    elif c in [stepw*0+1, stepw*1+1, stepw*2+1, stepw*3+1]:
        new_lon = lon - (stepw/2-1.5)*del_lon
        print('new lon=',new_lon)

    elif c in [stepw*0+2, stepw*1+2, stepw*2+2, stepw*3+2]:
        new_lon = lon - (stepw/2-2.5)*del_lon
        print('new lon=',new_lon)

    elif c in [stepw*0+3,stepw*1+3,stepw*2+3,c==stepw*3+3]:
        new_lon = lon + (stepw/2-2.5)*del_lon
        print('new lon=',new_lon)

    elif c in [stepw*0+4,stepw*1+4,stepw*2+4,c==stepw*3+4]:
        new_lon = lon + (stepw/2-1.5)*del_lon
        print('new lon=',new_lon)

    elif c in [stepw*0+5,stepw*1+5,stepw*2+5,c==stepw*3+5]:
        new_lon = lon + (stepw/2-.5)*del_lon
        print('new lon=',new_lon)

    else:
        print('lon num not defined', c)
        new_lon=lon

    #latitude
    if c in range(0,1*stepw):
        new_lat = lat + (steph/2-0.5)*lat_step
        print('new lat=',new_lat)

    elif c in range(1*stepw,2*stepw):
        new_lat = lat + (steph/2-1.5)*lat_step
        print('new lat=',new_lat)

    elif c in range(2*stepw,3*stepw):
        new_lat = lat + (steph/2-1.5)*lat_step
        print('new lat=',new_lat)

    elif c in range(3*stepw,4*stepw):
        new_lat = lat + (steph/2-0.5)*lat_step
        print('new lat=',new_lat)

    else:
        print('lat num not defined', c)
        new_lat=lat

    print('new_lat = ', new_lat, "old lat =", lat)
    print('new_lon = ',new_lon, "old lon =", lon)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-246-f53b95590097> in <module>()
#      13     #lat change equivalent depending on ground sampling distance of photo
#      14     #note -- explain how you got px500
# ---> 15     lat_step = px500*lat_per_m
#      16     lon_step = px500*lon_per_m
#      17
#
# NameError: name 'px500' is not defined

# %% [markdown]
# ## CHANGE LAT/LON IN EXIF

# %%
path_to_open = '/Users/elizabeth/Box Sync/deeplearningcourse/elizabeth/data/harrison_fieldwork1/images_wks1_2/testingexif/'
path_to_save = '/Users/elizabeth/Box Sync/deeplearningcourse/elizabeth/data/harrison_fieldwork1/images_wks1_2/testingexif/'
img = 'G0036562_4.JPG'

f = open(path_to_open+img, 'rb')

# Return Exif tags
exif_dict = piexif.load

#convert to decimal
lat = tags['GPS GPSLatitude'].values
lon = tags['GPS GPSLongitude'].values

lat = [float(i.num/i.den) for i in lat]
lon = [float(i.num/i.den) for i in lon]

lat = lat[0] + (lat[1])/60 + lat[2]/3600
lon = lon[0] + (lon[1])/60 + lon[2]/3600

#splices crop slice number from file name
c = int(re.sub("[^0-9]","",img[-6:]))

#longitude
#for i in range(stepw)

if c==stepw*0 | c==stepw*1 | c==stepw*2 | c==stepw*3:# | stepw*4 | stepw*5:
    new_lon = lon - (stepw/2-0.5)*del_lon
    print('new lon=',new_lon)

elif c==(stepw*0+1) | c==stepw*1+1 | c==stepw*2+1 | c==stepw*3+1:#| stepw*4+1 | stepw*5+1:
    new_lon = lon - (stepw/2-1.5)*del_lon
    print('new lon=',new_lon)
    
elif c==stepw*0+2 | c==stepw*1+2 | c==stepw*2+2 | c==stepw*3+2:
    new_lon = lon - (stepw/2-2.5)*del_lon
    print('new lon=',new_lon)
    
elif c in [stepw*0+3,stepw*1+3,stepw*2+3,c==stepw*3+3]:
    new_lon = lon + (stepw/2-2.5)*del_lon
    print('new lon=',new_lon)
    
elif c in [stepw*0+4,stepw*1+4,stepw*2+4,c==stepw*3+4]:
    new_lon = lon + (stepw/2-1.5)*del_lon
    print('new lon=',new_lon)
    
elif c in [stepw*0+5,stepw*1+5,stepw*2+5,c==stepw*3+5]:
    new_lon = lon + (stepw/2-.5)*del_lon
    print('new lon=',new_lon)
    
else:
    print('lon num not defined', c)
    new_lon=lon

#latitude
if c in range(0,1*stepw):
    new_lat = lat + (steph/2-0.5)*lat_step
    print('new lat=',new_lat)
    
elif c in range(1*stepw,2*stepw):
    new_lat = lat + (steph/2-1.5)*lat_step
    print('new lat=',new_lat)
    
elif c in range(2*stepw,3*stepw):
    new_lat = lat + (steph/2-1.5)*lat_step
    print('new lat=',new_lat)
    
elif c in range(3*stepw,4*stepw):
    new_lat = lat + (steph/2-0.5)*lat_step
    print('new lat=',new_lat)
    
else:
    print('lat num not defined', c)
    new_lat=lat

print('new_lat = ', new_lat, "old lat =", lat)
print('new_lon = ',new_lon, "old lon =", lon)
# Out:
# ('new lon=', 73.734519917327106)
# ('new lat=', 40.9670199173271)
# ('new_lat = ', 40.9670199173271, 'old lat =', 40.966944444444444)
# ('new_lon = ', 73.734519917327106, 'old lon =', 73.73444444444445)

# %%
exif_dict['GPS'][2] = new_lat
exif_dict['GPS'][4] = new_lon

exif_bytes = piexif.dump(exifdict)
im = Image.open(f)
im.save(path_to_save+f, exif=exif_bytes)

# %%
test = 'G0024061_22.JPG'

# %%
import re
re.sub("[^0-9]","",test[-6:])
# Out:
# '22'

# %%
for i in range(stepw)
    j = np.arange(0,steph)

    if c in (stepw+i)*np.arange(0,steph)
        new_lon = lon - (stepw/2-0.5)*del_lon
        print('new lon=',new_lon)

    elif c==(stepw*0+1) | c==stepw*1+1 | c==stepw*2+1 | c==stepw*3+1:#| stepw*4+1 | stepw*5+1:
        new_lon = lon - (stepw/2-1.5)*del_lon
        print('new lon=',new_lon)

    elif c==stepw*0+2 | c==stepw*1+2 | c==stepw*2+2 | c==stepw*3+2:
        new_lon = lon - (stepw/2-2.5)*del_lon
        print('new lon=',new_lon)

    elif c in [stepw*0+3,stepw*1+3,stepw*2+3,c==stepw*3+3]:
        new_lon = lon + (stepw/2-2.5)*del_lon
        print('new lon=',new_lon)

    elif c in [stepw*0+4,stepw*1+4,stepw*2+4,c==stepw*3+4]:
        new_lon = lon + (stepw/2-1.5)*del_lon
        print('new lon=',new_lon)

    elif c in [stepw*0+5,stepw*1+5,stepw*2+5,c==stepw*3+5]:
        new_lon = lon + (stepw/2-.5)*del_lon
        print('new lon=',new_lon)
        
    else:
        new_lon = lon

if new_lon == lon
    print('lon num not defined', c)
    new_lon=lon
